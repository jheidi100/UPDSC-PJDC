# %%
from textblob import TextBlob
import pandas as pd
import re

# %%
df = pd.read_csv("vaccination_all_tweets.csv")

# %%
df
# Out:
#                         id                   user_name  \
# 0      1340539111971516416                  Rachel Roh
# 1      1338158543359250433                 Albert Fong
# 2      1337858199140118533                    eli🇱🇹🇪🇺👌
# 3      1337855739918835717               Charles Adler
# 4      1337854064604966912        Citizen News Channel
# ...                    ...                         ...
# 40166  1373522034903420929  Stankevicius International
# 40167  1373517049184587776         Emanuele Capobianco
# 40168  1373514710033821705                          RT
# 40169  1373512948417695746             Sunday Observer
# 40170  1373503451372552197                   M a r t í
#
#                    user_location  \
# 0      La Crescenta-Montrose, CA
# 1              San Francisco, CA
# 2                       Your Bed
# 3         Vancouver, BC - Canada
# 4                            NaN
# ...                          ...
# 40166            Dublin, Ireland
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                         id                   user_name  \
# 0      1340539111971516416                  Rachel Roh
# 1      1338158543359250433                 Albert Fong
# 2      1337858199140118533                    eli🇱🇹🇪🇺👌
# 3      1337855739918835717               Charles Adler
# 4      1337854064604966912        Citizen News Channel
# ...                    ...                         ...
# 40166  1373522034903420929  Stankevicius International
# 40167  1373517049184587776         Emanuele Capobianco
# 40168  1373514710033821705                          RT
# 40169  1373512948417695746             Sunday Observer
# 40170  1373503451372552197                   M a r t í
#
#                    user_location  \
# 0      La Crescenta-Montrose, CA
# 1              San Francisco, CA
# 2                       Your Bed
# 3         Vancouver, BC - Canada
# 4                            NaN
# ...                          ...
# ...

# %%
#Reference: https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
def clean_text(text): 
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).lower().split())

def get_sentimentscore(cleaned_text): 
    sentiment_score = TextBlob(cleaned_text).sentiment.polarity
    return sentiment_score

def get_subjectivityscore(cleaned_text): 
    subjectivity_score = TextBlob(cleaned_text).sentiment.polarity 
    return subjectivity_score 

def categorize_sentiment(score): 
    if score > 0: 
        sentiment = "Positive"
    elif score < 0: 
        sentiment = "Negative"
    else: 
        sentiment = "Neutral"
    return sentiment

def categorize_subjectivity(score): 
    if score > 0: 
        subjectivity = "Subjective"
    elif score < 0: 
        subjectivity = "Not Subjective"
    else: 
        subjectivity = "Neutral"
    return subjectivity

# %%
df["cleaned_text"] = df["text"].apply(clean_text)

# %%
df["sentiment_score"] = df["cleaned_text"].apply(get_sentimentscore)

# %%
df["sentiment"] = df["sentiment_score"].apply(categorize_sentiment)

# %%
df["subjectivity_score"] = df["cleaned_text"].apply(get_subjectivityscore)

# %%
df["subjectivity"] = df["subjectivity_score"].apply(categorize_subjectivity)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                         id                   user_name  \
# 0      1340539111971516416                  Rachel Roh
# 1      1338158543359250433                 Albert Fong
# 2      1337858199140118533                    eli🇱🇹🇪🇺👌
# 3      1337855739918835717               Charles Adler
# 4      1337854064604966912        Citizen News Channel
# ...                    ...                         ...
# 40166  1373522034903420929  Stankevicius International
# 40167  1373517049184587776         Emanuele Capobianco
# 40168  1373514710033821705                          RT
# 40169  1373512948417695746             Sunday Observer
# 40170  1373503451372552197                   M a r t í
#
#                    user_location  \
# 0      La Crescenta-Montrose, CA
# 1              San Francisco, CA
# 2                       Your Bed
# 3         Vancouver, BC - Canada
# 4                            NaN
# ...                          ...
# ...

# %%
df.to_csv("Option B with Sentiment and Subjectivity Scores")
